# %%
import pandas as pd
import pprint as pp
import networkx as nx
import pickle
from operator import itemgetter, attrgetter

# %%
data_dir = './data/'

# %%
# Data
is_medium = False
get_empty = True
file_pre = 'medium' if is_medium else 'large'
empty_str = '_60percent_of_empty_profile'

graph = nx.read_gexf(data_dir + file_pre + 'Linkedin.gexf')
location = pd.read_pickle(data_dir + file_pre + 'Location.pickle')
employer = pd.read_pickle(data_dir + file_pre + 'Employer.pickle')
college = pd.read_pickle(data_dir + file_pre + 'College.pickle')

location_empty = pd.read_pickle(data_dir + file_pre + 'Location' + (empty_str if get_empty else '') + '.pickle')
employer_empty = pd.read_pickle(data_dir + file_pre + 'Employer' + (empty_str if get_empty else '') + '.pickle')
college_empty = pd.read_pickle(data_dir + file_pre + 'College' + (empty_str if get_empty else '') + '.pickle')
nodes_taken_out = pd.read_pickle(data_dir + file_pre + 'RemovedNodes_60percent_of_empty_profile.pickle')

# %%
# Add attributes to nodes in graph
possible_attributes = ['location', 'college', 'employer']

def addAttributes(G, attributes, attributes_name):
    nx.set_node_attributes(G, attributes, attributes_name)
        
def addAllAttributes(G):
        addAttributes(G, location_empty, 'location')
    addAttributes(G, employer_empty, 'employer')
    addAttributes(G, college_empty, 'college')

# %%
# Triangles 
# Check if new pair already considered in list, if not, it add it
def checkIfInPairsNewPair(triangles_pairs, node_1, node_2):
    if node_1 == node_2: return True
    for triangles_pair in triangles_pairs:
        if node_1 in triangles_pair and node_2 in triangles_pair: return True
    return False

# For one node, count number of trianlges with neighbors
def countTrianglesFromRelatedNodes(node, related_nodes, triangles_pairs):
    triangles_count = 0
    for related_node in related_nodes:  
        #print(f'checking pairs ({node}, {related_node})')
        if not checkIfInPairsNewPair(triangles_pairs, node, related_node): 
            #print(f'found coincidence')
            triangles_pairs.append((node, related_node))
            triangles_count += 0 if len(related_nodes) == 0 else 1
    return triangles_count

# Assumes, main node is already identified
# Delivers the quantity of triangles found and the array containing the pairs 
#   being the third one, the studied node
def locateTrianglesInNode(G, neighbors, node):
    triangles_count = 0
    triangles_pairs = []
    for n in neighbors:
        # convert to list in order to be able to use its properties
        neighbors_of_n = [n for n in G.neighbors(n)] 
        neighbors_of_n.remove(node) # ignore main node (node of study)
        related = [f_n for f_n in neighbors_of_n if f_n in neighbors]
        #print(f'neighbor: {n}, related {related}')
        triangles_count += countTrianglesFromRelatedNodes(n, related, triangles_pairs)
                
    return { 'triangles_count': triangles_count, 'triangles_pairs': triangles_pairs }

# %%
def searchFromAttributes(G, node_1, node_2, attributes):
    common_att = {}
    node_1_dict = G.nodes[node_1]
    node_2_dict = G.nodes[node_2]
    not_found_att = []
    for att in attributes:
        if att in node_1_dict and att in node_2_dict:
            node_1_att_values = node_1_dict[att]
            node_2_att_values = node_2_dict[att]
            #print(f'found att: {att}: {node_1_att_values} -- {node_2_att_values}')
            # find matches for att between both nodes
            for val in node_1_att_values:
                for val2 in node_2_att_values:
                    prepare_val = ''.join(val.lower().split(' ')) # prevent "errors of hand"
                    prepare_val2 = ''.join(val2.lower().split(' ')) #
                    if (prepare_val == prepare_val2): 
                        if not att in common_att: common_att[att] = []
                        common_att[att].append(val)
        else:
            not_found_att.append(att)
    #if (len(not_found_att) > 0): print('not found att: ', not_found_att)
    return common_att

def getPairRelationship(node_1, node_2, G, attributes):
    connections = searchFromAttributes(G, node_1, node_2, attributes)
    # --- do something else? ---
    return connections

def addValueToNode(G, node, value, attribute):
    node_attributes = G.nodes[node]
    #print(f'node att: {node_attributes}')
    new_values = []
    existant = False
    if attribute in node_attributes:
        new_values = node_attributes[attribute][:]
        prepare_val = ''.join(value.lower().split(' '))
        for val in new_values:
            joined_val = ''.join(val.lower().split(' '))
            if joined_val == prepare_val: 
                existant = True
                break
                
    new_values.append(value)
    #print(f'at node {node} new values: {new_values}')
    if not existant: addAttributes(G, { node: new_values }, attribute)

def verifyValueInAttribute(attribute, node_attributes, value):
    if attribute in node_attributes:
        new_values = node_attributes[attribute][:]
        prepare_val = ''.join(value.lower().split(' '))
        for val in new_values:
            joined_val = ''.join(val.lower().split(' '))
            if joined_val == prepare_val: 
                return True
    return False

def verifyAttributesInNode(attributes, node_attributes):
    total = len(attributes); this_total = 0
    for att in attributes: 
        if att in node_attributes: this_total += 1
    #if (this_total != total) and this_total > 0 : print(f'error? some att already: {this_total}')
    return (this_total == total)
        
def addValuesToNode(G, node, attribute, candidate_values):
    candidates = {}
    if verifyAttributesInNode(possible_attributes, G.nodes[node]): return # no need to analyze
    for index, candidate in enumerate(candidate_values):
        if index in candidates:  candidates[index] += 1
        else: candidates[index] = 1       
        
    # Decision Rules
    values_to_add = []
    if len(candidates) == 0: 
        #print('zero candidates'); 
        return
    elif len(candidates) == 1: 
        #print('one candidate');
        values_to_add = [candidate_values[0]]
    else:
        #print('several candidates');
        weights = [v for i, v in candidates.items()]
        max_weight = max(weights)
        indexes = [ i for i, v in candidates.items() if max_weight == v ]
        values_to_add = [ candidate_values[i] for i in indexes ]
        
    addAttributes(G, { node: values_to_add }, attribute)

# %%
# Obtain desired nodes, where to start searching, idealy in the nodes that have all the information

def checkIfAttributes(node, attributes):
    for att in attributes:
        if not att in node: return False
    return True

def checkWellLabeledNodes(G):
    well_labeled_nodes = []
    for node in G.nodes:
        if not checkIfAttributes(G.nodes[node], possible_attributes): continue
        neighbors = [n for n in G.neighbors(node)]
        completed = True
        for neighbor in neighbors:
            if not checkIfAttributes(G.nodes[neighbor], possible_attributes): 
                completed = False
                break
        if not completed : continue
        # passed both tests, good places to start:
        well_labeled_nodes.append(node)
    return well_labeled_nodes

# %%
# ---- RUN FOR AL DESIRED NODES -----

def firstProposal(G):
    addAllAttributes(G)
    well_labeled_nodes = checkWellLabeledNodes(G)
    pipe = [node for node in well_labeled_nodes if node in nodes_with_triangles]
    pipe = pipe + [node for node in G.nodes if node not in pipe]

    for node in pipe:
        neighbors = [n for n in G.neighbors(node)]
        triangles_in_node = locateTrianglesInNode(G, neighbors, node)

        prepare_new_values = {}
        for pair in triangles_in_node['triangles_pairs']:
            connections = getPairRelationship(pair[0], pair[1], G, possible_attributes)
            for att, matches in connections.items():
                # addValuesToNode(G, node, att, matches)
                for match in matches:
                    addValueToNode(G, node, match, att)

# %%
# ---- RUN FOR AL DESIRED NODES SECOND PROPOSAL -----
def secondProposal(G):
    addAllAttributes(G)
    well_labeled_nodes = checkWellLabeledNodes(G)
    pipe = [node for node in well_labeled_nodes if node in nodes_with_triangles]
    pipe = pipe + [node for node in G.nodes if node not in pipe]

    for node in pipe:
        neighbors = [n for n in G.neighbors(node)]
        triangles_in_node = locateTrianglesInNode(G, neighbors, node)

        for pair in triangles_in_node['triangles_pairs']:
            connections = getPairRelationship(pair[0], pair[1], G, possible_attributes)
            #print(connections)
            for att, matches in connections.items():
                #print(f'att: { att}, match: { matches}')
                addValuesToNode(G, node, att, matches)

# %%
# Get info as neeeded for evaluation
def extractFromGraph(G, attribute):
    extracted = {}
    for node in G.nodes:
        node_att = G.nodes[node]
        if attribute in node_att: extracted[node] = node_att[attribute]
    return extracted

# %%
def evaluation_accuracy(groundtruth, pred):
    """    Compute the accuracy of your model.

     The accuracy is the proportion of true results.

    Parameters
    ----------
    groundtruth :  : dict 
       A dict of attributes, either location, employer or college attributes. 
       key is a node, value is a list of attribute values.
    pred : dict 
       A dict of attributes, either location, employer or college attributes. 
       key is a node, value is a list of attribute values. 

    Returns
    -------
    out : float
       Accuracy.
    """
    true_positive_prediction=0   
    for p_key, p_value in pred.items():
        if p_key in groundtruth:
            # if prediction is no attribute values, e.g. [] and so is the groundtruth
            # May happen
            if not p_value and not groundtruth[p_key]:
                true_positive_prediction+=1
            # counts the number of good prediction for node p_key
            # here len(p_value)=1 but we could have tried to predict more values
            true_positive_prediction += len([c for c in p_value if c in groundtruth[p_key]])          
        # no else, should not happen: train and test datasets are consistent
    return true_positive_prediction*100/sum(len(v) for v in pred.values())


def getLeoInfo(G, att, in_dict_or_arr, groundtruth):
    los_q_quiere_leo = {}
    los_q_quiere_leo = { node: values for node, values in extractFromGraph(G, att).items() if node in in_dict_or_arr }
    print(f'# {len(los_q_quiere_leo)}')
    print(f'for {att}: {evaluation_accuracy(groundtruth,los_q_quiere_leo)}')

# %%
#Third Proposal dev

def updateNodeInfoInPipe(G, pipe, node, labeled_nodes, first_time = False):
    some_change = False
    neighbors = [n for n in G.neighbors(node)]
    well_labeled_neighbors = [n for n in neighbors if n in labeled_nodes]
    triangles_in_node = locateTrianglesInNode(G, neighbors, node)
    info_availability_percentage = len(well_labeled_neighbors) / len(neighbors) if triangles_in_node['triangles_count'] > 0 else 0
    node_info = {
        'node': node,
        'total_neigh': len(neighbors),
        'total_labeled_neigh': len(well_labeled_neighbors),
        'info_availability_percentage': info_availability_percentage,
        'trianlges': triangles_in_node['triangles_count'],
        'labels': len(G.nodes[node]) - 1,
    }
    if first_time: pipe.append(node_info); return True
    for node_dict in pipe:
        if node_dict['node'] == node:
            if not node_dict['info_availability_percentage'] == node_info['info_availability_percentage']: some_change = True;
            if node_dict['labels'] != len(G.nodes[node]) - 1: some_change = True
            node_dict['total_labeled_neigh'] = node_info['total_labeled_neigh']
            node_dict['info_availability_percentage'] = node_info['info_availability_percentage']
            node_dict['labels'] = len(G.nodes[node]) - 1
            break
    return some_change

def thirdProposal(G, nodes_taken_out):
    addAllAttributes(G)
    labeled_nodes = [n for n in G.nodes if n not in nodes_taken_out]

    pipe = []
    for node in nodes_taken_out:
        updateNodeInfoInPipe(G, pipe, node, labeled_nodes, True)
    
    #order the pipe
    pipe = sorted(pipe, key=itemgetter('info_availability_percentage'), reverse=True)

    some_change = True
    count = 0
    while some_change and count < 100:
        some_change = False
        count += 1
        for i, node_info in enumerate(pipe):
            node = node_info['node']
            neighbors = [n for n in G.neighbors(node)]
            triangles_in_node = locateTrianglesInNode(G, neighbors, node)
            for pair in triangles_in_node['triangles_pairs']:
                connections = getPairRelationship(pair[0], pair[1], G, possible_attributes)
                for att, matches in connections.items():
                    addValuesToNode(G, node, att, matches)
            some_change = updateNodeInfoInPipe(G, pipe, node, labeled_nodes) or some_change
            if pipe[i]['total_neigh'] == pipe[i]['total_labeled_neigh']: 
                labeled_nodes.append(pipe[i])
                del pipe[i]

# %%
# Studying nodes, discovered 3 kinds of them: nodes with triangles, one link nodes and several link nodes
# Obtain the nodes with trianlges, and the other 2 cases

def getDifferentQuantitiesForAttackingGraph(G):
    count_triangles = 0
    count_one_neighbor = 0
    count_plus_neighbors = 0
    nodes_with_triangles = []
    nodes_one_neighbor = []
    nodes_plus_neighbors = []
    for node in G.nodes:
        neighbors = [n for n in G.neighbors(node)]
        triangles_in_node = locateTrianglesInNode(G, neighbors, node)
        if triangles_in_node['triangles_count'] == 0 and len(neighbors) > 1: 
            count_plus_neighbors += 1
            nodes_plus_neighbors.append(node)
            #print('----SUP--- node: ', node , ' count: ', len(neighbors))
        elif triangles_in_node['triangles_count'] == 0 and len(neighbors) == 1:
            count_one_neighbor += 1
            #print('----EQUAL--- node: ', node)
            nodes_one_neighbor.append(node)
        else:
            count_triangles += 1
            nodes_with_triangles.append(node)
        #print('----TRI--- qty: ', triangles_in_node['triangles_count'])
    return { 
        'nodes_with_triangles': nodes_with_triangles,
        'nodes_one_neighbor': nodes_one_neighbor,
        'nodes_plus_neighbors': nodes_plus_neighbors,
        'count_triangles': count_triangles,
        'count_one_neighbor': count_one_neighbor,
        'count_plus_neighbors': count_plus_neighbors
    }

#print('# of nodes w/triangles: ', count_triangles, ' # of same with no: ', count_non_tri_easy, ' others: ', count_non_tri)
#print(count_triangles + count_non_tri_easy + count_non_tri)

# %%
# this method assumes that the values to evaluate are inside G
def accuracyEvaluation(G, attributes, groundtruth_dict, evaluate_this_nodes_dict = {}, this_nodes_title = ''):
    results = {}
    total_nodes = len(G)
    for att in attributes:
        correctness = wrongness = missingness = 0
        
        if att in groundtruth_dict:
            groundtruth = groundtruth_dict[att]
            correct = wrong = missing = 0
            for node in G.nodes:
                truth_values = groundtruth[node]
                node_att = G.nodes[node]
                if att not in node_att: missing += len(truth_values); continue;
                calculated = node_att[att]
                for val in truth_values:
                    if val in calculated: correct += 1
                    else: missing += 1
                for val in calculated:
                    if val not in truth_values: wrong += 1
            correctness = 100 * correct / (correct + missing)
            wrongness = 100 * wrong / (correct + missing)
            missingness = 100 * missing / (correct + missing)
            results[att] = { 
                '1_total_correct': correct, 
                '1_total_wrong': wrong, 
                '1_total_missing': missing,
                '3_overall_correctness': correctness, 
                '3_overall_wrongness': wrongness,
                '3_overall_missingness': missingness
            }
        if att in evaluate_this_nodes_dict and att in groundtruth_dict:
            evaluate_dict = evaluate_this_nodes_dict[att]
            groundtruth = groundtruth_dict[att]
            correct = wrong = missing = 0
            for node in evaluate_dict:
                truth_values = groundtruth[node]
                node_att = G.nodes[node]
                if att not in node_att: missing += len(truth_values); continue;
                calculated = node_att[att]
                for val in truth_values:
                    if val in calculated: correct += 1
                    else: missing += 1
                for val in calculated:
                    if val not in truth_values: wrong += 1
            correctness = 100 * correct / (correct + missing)
            wrongness = 100 * wrong / (correct + missing)
            missingness = 100 * missing / (correct + missing)
            located_str = this_nodes_title if this_nodes_title != '' else 'located'
            results[att]['4_' + located_str + '_correct'] = correct
            results[att]['4_' + located_str + '_wrong'] = wrong
            results[att]['4_' + located_str + '_missing'] = missing
            results[att]['5_' + located_str + '_correctness'] = correctness
            results[att]['5_' + located_str + '_wrongness'] = wrongness
            results[att]['5_' + located_str + '_missingness'] = missingness
        
        pp.pprint(results)
    results['graph_len'] = total_nodes
    return results

# %%
graph_first = nx.read_gexf(data_dir + file_pre + 'Linkedin.gexf')

# %%
diff_qtt = getDifferentQuantitiesForAttackingGraph(graph_first)
pp.pprint(diff_qtt, depth=1)
nodes_with_triangles = diff_qtt['nodes_with_triangles']
# Out:
# {'count_one_neighbor': 5211,
#  'count_plus_neighbors': 22,
#  'count_triangles': 8799,
#  'nodes_one_neighbor': [...],
#  'nodes_plus_neighbors': [...],
#  'nodes_with_triangles': [...]}

# %%
thirdProposal(graph_first, nodes_taken_out)
#secondProposal(graph_first)
#firstProposal(graph_first)

# %%
loc_att = nx.get_node_attributes(graph_first, 'location')
col_att = nx.get_node_attributes(graph_first, 'college')
emp_att = nx.get_node_attributes(graph_first, 'employer')
with open('./output/location' + 'FirstProposal' + file_pre + '.pickle', 'wb') as handle:
    pickle.dump(loc_att, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('./output/college' + 'FirstProposal' + file_pre + '.pickle', 'wb') as handle:
    pickle.dump(col_att, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('./output/employer' + 'FirstProposal' + file_pre + '.pickle', 'wb') as handle:
    pickle.dump(emp_att, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
attributes = ['location']
groundtruth_dict = { 'location': location, 'employer': employer, 'college': college }
located_to_study = {}
#located_to_study['location'] = extractFromGraph(graph_first, "location")
located_to_study['location'] = { node: 0 for node in nodes_with_triangles } 
located_to_study['employer'] = { node: 0 for node in nodes_with_triangles } 
located_to_study['college'] = { node: 0 for node in nodes_with_triangles } 
title = 'nodes_with_triangles'
results = accuracyEvaluation(graph_first, attributes, groundtruth_dict, located_to_study, title)
# Out:
# {'location': {'1_total_correct': 404,
#               '1_total_missing': 407,
#               '1_total_wrong': 73,
#               '3_overall_correctness': 49.81504315659679,
#               '3_overall_missingness': 50.18495684340321,
#               '3_overall_wrongness': 9.001233045622689,
#               '4_nodes_with_triangles_correct': 249,
#               '4_nodes_with_triangles_missing': 181,
#               '4_nodes_with_triangles_wrong': 73,
#               '5_nodes_with_triangles_correctness': 57.906976744186046,
#               '5_nodes_with_triangles_missingness': 42.093023255813954,
#               '5_nodes_with_triangles_wrongness': 16.976744186046513}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-194-97091699f74e> in <module>
#       7 located_to_study['college'] = { node: 0 for node in nodes_with_triangles }
#       8 title = 'nodes_with_triangles'
# ----> 9 results = accuracyEvaluation(graph_first, attributes, groundtruth_dict, located_to_study, title)
#
# <ipython-input-95-ef517814e698> in accuracyEvaluation(G, attributes, groundtruth_dict, evaluate_this_nodes_dict, this_nodes_title)
#      10             correct = wrong = missing = 0
#      11             for node in G.nodes:
# ---> 12                 truth_values = groundtruth[node]
#      13                 node_att = G.nodes[node]
#      14                 if att not in node_att: missing += len(truth_values); continue;
#
# KeyError: 'U14078'

# %%
#nodes_one_neighbor = diff_qtt['nodes_one_neighbor']
#nodes_plus_neighbors = diff_qtt['nodes_plus_neighbors']
graph_all = nx.read_gexf(data_dir + file_pre + 'Linkedin.gexf')
addAttributes(graph_all, location, 'location')
addAttributes(graph_all, college, 'college')
addAttributes(graph_all, employer, 'employer')
"""
for node in nodes_one_neighbor:
    neighbors = [n for n in graph_all.neighbors(node)]
    neighbor = neighbors[0]
    print('---- node ----')
    relationship = getPairRelationship(node, neighbor, graph_all, possible_attributes)
    
    if 'location' not in relationship and 'employer' not in relationship and 'college' not in relationship:
        print(f'--> START NOOOOOOOOT node1: {node}, node2: {neighbor}')
        pp.pprint(graph_all.nodes[node])
        pp.pprint(graph_all.nodes[neighbor])
        print('--> END NOOOOOOOOT ')
    else:
        print('--> COIN ')
        print(relationship)"""
# Out:
# "\nfor node in nodes_one_neighbor:\n    neighbors = [n for n in graph_all.neighbors(node)]\n    neighbor = neighbors[0]\n    print('---- node ----')\n    relationship = getPairRelationship(node, neighbor, graph_all, possible_attributes)\n    \n    if 'location' not in relationship and 'employer' not in relationship and 'college' not in relationship:\n        print(f'--> START NOOOOOOOOT node1: {node}, node2: {neighbor}')\n        pp.pprint(graph_all.nodes[node])\n        pp.pprint(graph_all.nodes[neighbor])\n        print('--> END NOOOOOOOOT ')\n    else:\n        print('--> COIN ')\n        print(relationship)"

# %%
node = 'U22859'
second_neighbors = [n for n in graph_all.neighbors('U22747')]
for neigh in second_neighbors:
    relationship = getPairRelationship(node, neigh, graph_all, possible_attributes)
    print(relationship)
# Out:
# {'location': ['bengaluru area india'], 'college': ['indian institute of technology madras'], 'employer': ['amazon', 'ibm india research lab', 'coordinated science lab', 'toyota technical center']}
# {}
# {}
# {'location': ['bengaluru area india']}
# {}
# {'location': ['bengaluru area india']}
# {'location': ['bengaluru area india']}
# {}
# {}
# {'location': ['bengaluru area india']}
# {}
# {}
# {}
# {'employer': ['amazon']}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {}
# {'college': ['indian institute of technology madras']}
# {}
# {}
# {'location': ['bengaluru area india']}
# {}

# %%
# Understand percentages of coincidences of each attribute in first and second grade neighbors

# First
total_nodes = len(nodes_one_neighbor)
college_matches = 0
employer_matches = 0
location_matches = 0
location_percentage = 0
college_percentage = 0
employer_percentage = 0
for node in nodes_one_neighbor:
    neighbors = [n for n in graph_all.neighbors(node)]
    neighbor = neighbors[0]
    relationships = getPairRelationship(node, neighbor, graph_all, possible_attributes)
    #print('----node----')
    len_att = len(relationships)
    for att, values in relationships.items():
        if att == 'location': location_matches += 1; location_percentage += 1/len_att; #print(f'matches: {len(values)}')
        elif att == 'college': college_matches += 1; college_percentage += 1/len_att; #print(f'matches: {len(values)}')
        elif att == 'employer': employer_matches += 1; employer_percentage += 1/len_att; #print(f'matches: {len(values)}')
        else: print('error')

print(f'MATCHES -> attribute (matches with neighbor)||(matches according to total of matches of attribute)||(matches/nodes -> accuracy?)')
print(f'MATCHES -> college {college_matches}||{college_percentage}||{100*college_matches/total_nodes}')
print(f'MATCHES -> employer: {employer_matches}||{employer_percentage}||{100*employer_matches/total_nodes}') 
print(f'MATCHES -> location: {location_matches}||{location_percentage}||{100*location_matches/total_nodes}')

# Second
college_matches = 0
employer_matches = 0
location_matches = 0
location_percentage = 0
college_percentage = 0
employer_percentage = 0
total_nodes = 0
for node in nodes_one_neighbor:
    neighbors = [n for n in graph_all.neighbors(node)]
    neighbor = neighbors[0]
    second_neighbors = [n for n in graph_all.neighbors(neighbor)]
    relationships = getPairRelationship(node, neighbor, graph_all, possible_attributes)
    #
    #if len(relationships) > 0: continue
    len_second_neigh = len(second_neighbors)
    total_nodes += len_second_neigh
    for neigh in second_neighbors:
        relationships = getPairRelationship(node, neigh, graph_all, possible_attributes)
        len_att = len(relationships)
        for att, values in relationships.items():
            if att == 'location': location_matches += 1; location_percentage += 1/(len_att*len_second_neigh); #print(f'matches: {len(values)}')
            elif att == 'college': college_matches += 1; college_percentage += 1/(len_att*len_second_neigh); #print(f'matches: {len(values)}')
            elif att == 'employer': employer_matches += 1; employer_percentage += 1/(len_att*len_second_neigh); #print(f'matches: {len(values)}')
            else: print('error')
print('\n')
print(f'MATCHES -> attribute (total matches per attribute)||(percentage of fiability according to matches)||(percentage fiability according total nodes studied)')
print(f'MATCHES -> college {college_matches}||{college_percentage}||{100*college_matches/total_nodes}')
print(f'MATCHES -> employer: {employer_matches}||{employer_percentage}||{100*employer_matches/total_nodes}') 
print(f'MATCHES -> location: {location_matches}||{location_percentage}||{100*location_matches/total_nodes}')


# Second
college_matches = 0
employer_matches = 0
location_matches = 0
location_percentage = 0
college_percentage = 0
employer_percentage = 0
total_nodes = 0
for node in nodes_one_neighbor:
    neighbors = [n for n in graph_all.neighbors(node)]
    neighbor = neighbors[0]
    second_neighbors = [n for n in graph_all.neighbors(neighbor)]
    relationships = getPairRelationship(node, neighbor, graph_all, possible_attributes)
    if len(relationships) > 0: continue
    len_second_neigh = len(second_neighbors)
    total_nodes += len_second_neigh
    most_repeated_rel = {}
    for neigh in second_neighbors:
        relationships = getPairRelationship(node, neigh, graph_all, possible_attributes)
        len_att = len(relationships)
        for att, values in relationships.items():
            if not att in most_repeated_rel: most_repeated_rel[att] = {}
            if att == 'location': 
                location_matches += 1; 
                location_percentage += 1/(len_att*len_second_neigh); #print(f'matches: {len(values)}')
            elif att == 'college': 
                college_matches += 1; 
                college_percentage += 1/(len_att*len_second_neigh); #print(f'matches: {len(values)}')
            elif att == 'employer': 
                employer_matches += 1; 
                employer_percentage += 1/(len_att*len_second_neigh); #print(f'matches: {len(values)}')
            else: print('error')
            for value in values:
                if not value in most_repeated_rel[att] : most_repeated_rel[att][value] = 0
                most_repeated_rel[att][value] += 1
    print(relationships)
    print(most_repeated_rel)
print('\n')
print(f'MATCHES -> attribute (total matches per attribute)||(percentage of fiability according to matches)||(percentage fiability according total nodes studied)')
print(f'MATCHES -> college {college_matches}||{college_percentage}||{100*college_matches/total_nodes}')
print(f'MATCHES -> employer: {employer_matches}||{employer_percentage}||{100*employer_matches/total_nodes}') 
print(f'MATCHES -> location: {location_matches}||{location_percentage}||{100*location_matches/total_nodes}')

# con esto podemos ver que para cuando se tiene el vecino bien labeled, se puede asisgnar location con 56%
# de éxito y sino acudir a sus vecinos y asignar location con 23% de éxito aprox
# Out:
# MATCHES -> attribute (matches with neighbor)||(matches according to total of matches of attribute)||(matches/nodes -> accuracy?)
# MATCHES -> college 58||43.16666666666667||17.008797653958943
# MATCHES -> employer: 57||35.66666666666666||16.715542521994134
# MATCHES -> location: 74||56.16666666666667||21.700879765395893
#
#
# MATCHES -> attribute (total matches per attribute)||(percentage of fiability according to matches)||(percentage fiability according total nodes studied)
# MATCHES -> college 1956||28.65213432954574||10.960439314132019
# MATCHES -> employer: 1434||23.99486847834699||8.0354140983974
# MATCHES -> location: 2652||50.33886256979451||14.86047293511151
# {}
# {'location': {'bengaluru area india': 6}, 'college': {'indian institute of technology madras': 2}, 'employer': {'amazon': 2, 'ibm india research lab': 1, 'coordinated science lab': 1, 'toyota technical center': 1}}
# {}
# {'location': {'baltimore maryland area': 1}, 'employer': {'designing events': 1}}
# {}
# {'location': {'davenport iowa area': 1}, 'employer': {'john deere': 1}}
# {'location': ['greater chicago area'], 'college': ['university of illinois at urbana-champaign']}
# {'location': {'greater chicago area': 20}, 'college': {'university of illinois at urbana-champaign': 26}, 'employer': {'chicago review press': 1, 'dalkey archive press': 1}}
# {'location': ['greater chicago area']}
# {'location': {'greater chicago area': 20}, 'college': {'illinois wesleyan university': 1}, 'employer': {'chicago public schools': 2, 'illinois wesleyan development department': 1, 'children&#x2019;s discovery museum': 1, 'martin flory group': 1}}
# {'college': ['university of illinois at urbana-champaign'], 'employer': ['university of illinois at urbana-champaign']}
# {'college': {'university of illinois at urbana-champaign': 26}, 'location': {'kansas city missouri area': 1}, 'employer': {'kipp endeavor academy': 1, 'illinois leadership center': 1, 'university of illinois at urbana-champaign': 13, 'bulls sox training academy': 1}}
# {}
# {'location': {'beijing city china': 3}, 'college': {'beihang university': 1}, 'employer': {'zgift.cn': 1, 'chinafung.com': 1}}
# {'location': {'san francisco bay area': 21}, 'employer': {'linkedin': 3, 'morgan stanley smith barney': 1, 'bizmerge inc.': 1, 'pacific gas &amp; electric': 1, 'alpha kappa psi': 1}, 'college': {'university of california irvine': 1}}
# {'location': ['west palm beach florida area'], 'college': ['florida atlantic university'], 'employer': ['floorforce llc.']}
# {'location': {'west palm beach florida area': 3}, 'college': {'florida atlantic university': 2}, 'employer': {'floorforce llc.': 1}}
#
#
# MATCHES -> attribute (total matches per attribute)||(percentage of fiability according to matches)||(percentage fiability according total nodes studied)
# MATCHES -> college 351||6.826363366828028||3.4213861000097476
# MATCHES -> employer: 403||7.9485500615450615||3.9282581148260065
# MATCHES -> location: 1118||23.4116846232819||10.897748318549565

# %%
for node in graph_all:
    node_att = graph_all.nodes[node]
    if 'location' in node_att:
        value = graph_all.nodes[node]['location'][0]
        nx.set_node_attributes(graph_all, { node: value }, 'location')

# %%
nx.attribute_assortativity_coefficient(graph_all, 'location')
# Out:
# 0.13056238121454491

# %%
print(len(graph_all))
print(len(graph_first))
# Out:
# 811
# 811

# %%
centrality_degree = nx.degree_centrality(graph_first)
centrality_degree
# Out:
# {'U27476': 0.009876543209876543,
#  'U4665': 0.012345679012345678,
#  'U1313': 0.0049382716049382715,
#  'U8804': 0.0012345679012345679,
#  'U14078': 0.0049382716049382715,
#  'U9628': 0.006172839506172839,
#  'U9721': 0.0024691358024691358,
#  'U2649': 0.0024691358024691358,
#  'U27759': 0.0012345679012345679,
#  'U7310': 0.0012345679012345679,
#  'U22859': 0.0012345679012345679,
#  'U1417': 0.0012345679012345679,
#  'U25611': 0.003703703703703704,
#  'U24095': 0.0049382716049382715,
#  'U3895': 0.009876543209876543,
#  'U13005': 0.0024691358024691358,
#  'U2620': 0.0012345679012345679,
#  'U5976': 0.008641975308641974,
#  'U4249': 0.019753086419753086,
#  'U9140': 0.003703703703703704,
#  'U16112': 0.003703703703703704,
#  'U27776': 0.0012345679012345679,
#  'U27708': 0.0024691358024691358,
#  'U15284': 0.006172839506172839,
#  'U24549': 0.0012345679012345679,
#  'U18514': 0.024691358024691357,
#  'U15272': 0.007407407407407408,
#  'U3933': 0.003703703703703704,
#  'U15946': 0.007407407407407408,
#  'U25630': 0.003703703703703704,
#  'U25632': 0.0012345679012345679,
#  'U22031': 0.0012345679012345679,
#  'U11562': 0.009876543209876543,
#  'U22071': 0.0012345679012345679,
#  'U15292': 0.011111111111111112,
#  'U7912': 0.020987654320987655,
#  'U22018': 0.0012345679012345679,
#  'U18925': 0.0012345679012345679,
#  'U7136': 0.0012345679012345679,
#  'U14498': 0.0049382716049382715,
#  'U21990': 0.0012345679012345679,
#  'U3927': 0.0024691358024691358,
#  'U1381': 0.0012345679012345679,
#  'U22087': 0.0012345679012345679,
#  'U27804': 0.0012345679012345679,
#  'U24252': 0.003703703703703704,
#  'U7355': 0.007407407407407408,
#  'U12969': 0.006172839506172839,
#  'U2180': 0.006172839506172839,
#  'U11815': 0.0049382716049382715,
#  'U4447': 0.0012345679012345679,
#  'U27679': 0.0012345679012345679,
#  'U27582': 0.0049382716049382715,
#  {'node': 'U4685', 'centr': 0.0012345679012345679},
#  {'node': 'U22002', 'centr': 0.0012345679012345679},
#  {'node': 'U14150', 'centr': 0.0012345679012345679},
#  {'node': 'U7281', 'centr': 0.0012345679012345679},
#  {'node': 'U18557', 'centr': 0.0012345679012345679},
#  {'node': 'U7141', 'centr': 0.0012345679012345679},
#  {'node': 'U1379', 'centr': 0.0012345679012345679},
#  {'node': 'U18586', 'centr': 0.0012345679012345679},
#  {'node': 'U22076', 'centr': 0.0012345679012345679},
#  {'node': 'U7074', 'centr': 0.0012345679012345679},
#  {'node': 'U21969', 'centr': 0.0012345679012345679},
#  {'node': 'U22073', 'centr': 0.0012345679012345679},
#  {'node': 'U24179', 'centr': 0.0012345679012345679},
#  {'node': 'U22849', 'centr': 0.0012345679012345679},
#  {'node': 'U1119', 'centr': 0.0012345679012345679},
#  {'node': 'U24224', 'centr': 0.0012345679012345679},
#  {'node': 'U7402', 'centr': 0.0012345679012345679},
#  {'node': 'U7156', 'centr': 0.0012345679012345679},
#  {'node': 'U16098', 'centr': 0.0012345679012345679},
#  {'node': 'U8110', 'centr': 0.0012345679012345679},
#  {'node': 'U22820', 'centr': 0.0012345679012345679},
#  {'node': 'U27777', 'centr': 0.0012345679012345679},
#  {'node': 'U7189', 'centr': 0.0012345679012345679},
#  {'node': 'U27798', 'centr': 0.0012345679012345679},
#  {'node': 'U7199', 'centr': 0.0012345679012345679},
#  {'node': 'U18520', 'centr': 0.0012345679012345679}]

# %%
cnt = 0
total_len = len(graph_first)
for index, node_element in enumerate(order_arr):
    if node_element['node'] in nodes_with_triangles: 
        print(f'index { index }')
        
# with this, we can see that the most central nodes are already included in the nodes with triangles study
# Out:
# index 0
# index 1
# index 2
# index 3
# index 4
# index 5
# index 6
# index 7
# index 8
# index 9
# index 10
# index 11
# index 12
# index 13
# index 14
# index 15
# index 16
# index 17
# index 18
# index 19
# index 20
# index 21
# index 22
# index 23
# index 24
# index 25
# index 26
# index 27
# index 28
# index 29
# index 30
# index 31
# index 32
# index 33
# index 34
# index 35
# index 36
# index 37
# index 38
# index 39
# index 40
# index 41
# index 42
# index 43
# index 44
# index 45
# index 46
# index 47
# index 48
# index 49
# index 50
# index 51
# index 52
# index 53
# index 54
# index 55
# index 56
# index 57
# index 58
# index 59
# index 60
# index 61
# index 62
# index 63
# index 64
# index 65
# index 66
# index 67
# index 68
# index 69
# index 70
# index 71
# index 72
# index 73
# index 74
# index 75
# index 76
# index 77
# index 78
# index 79
# index 80
# index 81
# index 82
# index 83
# index 84
# index 85
# index 86
# index 87
# index 88
# index 89
# index 90
# index 91
# index 92
# index 93
# index 94
# index 95
# index 96
# index 97
# index 98
# index 99
# index 100
# index 101
# index 102
# index 103
# index 104
# index 105
# index 106
# index 107
# index 108
# index 109
# index 110
# index 111
# index 112
# index 113
# index 114
# index 115
# index 116
# index 117
# index 118
# index 119
# index 120
# index 121
# index 122
# index 123
# index 124
# index 125
# index 126
# index 127
# index 128
# index 129
# index 130
# index 131
# index 132
# index 133
# index 134
# index 135
# index 136
# index 137
# index 138
# index 139
# index 140
# index 141
# index 142
# index 143
# index 144
# index 145
# index 146
# index 147
# index 148
# index 149
# index 150
# index 151
# index 152
# index 153
# index 154
# index 155
# index 156
# index 158
# index 159
# index 160
# index 161
# index 162
# index 163
# index 164
# index 165
# index 166
# index 167
# index 168
# index 169
# index 170
# index 171
# index 172
# index 173
# index 174
# index 175
# index 176
# index 177
# index 178
# index 179
# index 180
# index 182
# index 183
# index 184
# index 185
# index 186
# index 187
# index 188
# index 189
# index 190
# index 191
# index 192
# index 193
# index 194
# index 195
# index 196
# index 197
# index 198
# index 199
# index 200
# index 201
# index 202
# index 203
# index 204
# index 205
# index 207
# index 208
# index 209
# index 210
# index 211
# index 212
# index 213
# index 214
# index 215
# index 216
# index 217
# index 218
# index 219
# index 220
# index 221
# index 222
# index 223
# index 224
# index 225
# index 226
# index 227
# index 228
# index 229
# index 230
# index 231
# index 232
# index 233
# index 234
# index 235
# index 236
# index 237
# index 238
# index 239
# index 240
# index 241
# index 242
# index 243
# index 244
# index 245
# index 246
# index 247
# index 248
# index 249
# index 250
# index 252
# index 253
# index 254
# index 255
# index 256
# index 257
# index 258
# index 260
# index 261
# index 262
# index 263
# index 264
# index 265
# index 266
# index 267
# index 268
# index 269
# index 270
# index 271
# index 272
# index 273
# index 274
# index 275
# index 276
# index 277
# index 278
# index 279
# index 280
# index 281
# index 282
# index 283
# index 284
# index 285
# index 286
# index 287
# index 288
# index 289
# index 290
# index 291
# index 292
# index 293
# index 294
# index 295
# index 296
# index 297
# index 298
# index 299
# index 300
# index 301
# index 303
# index 304
# index 305
# index 306
# index 307
# index 309
# index 310
# index 311
# index 312
# index 313
# index 314
# index 315
# index 317
# index 318
# index 319
# index 320
# index 321
# index 323
# index 324
# index 325
# index 327
# index 328
# index 329
# index 330
# index 331
# index 332
# index 333
# index 335
# index 336
# index 337
# index 338
# index 339
# index 340
# index 342
# index 343
# index 344
# index 347
# index 348
# index 350
# index 351
# index 353
# index 354
# index 356
# index 357
# index 360
# index 362
# index 363
# index 364
# index 366
# index 367
# index 368
# index 369
# index 370
# index 371
# index 372
# index 373
# index 374
# index 375
# index 377
# index 378
# index 380
# index 381
# index 382
# index 383
# index 384
# index 386
# index 388
# index 391
# index 392
# index 393
# index 394
# index 395
# index 396
# index 397
# index 398
# index 399
# index 401
# index 402
# index 403
# index 404
# index 405
# index 406
# index 407
# index 409
# index 411
# index 412
# index 414
# index 415
# index 416
# index 418
# index 419
# index 420
# index 421
# index 422
# index 423
# index 424
# index 425
# index 426
# index 427
# index 428
# index 429
# index 430
# index 434
# index 435
# index 436
# index 437
# index 438
# index 439
# index 440
# index 443
# index 444
# index 446
# index 447
# index 448
# index 449
# index 450
# index 451
# index 453
# index 454
# index 455
# index 456
# index 457
# index 458
# index 459
# index 460
# index 461
# index 462
# index 464
# index 465
# index 466
# index 467
# index 468
# index 469

# %%
nx.attribute_mixing_dict(graph_all, 'location')
# Out:
# {'greater new york city area': {'san francisco bay area': 7,
#   'shanghai city china': 2,
#   'greater seattle area': 2,
#   'greater san diego area': 2,
#   'china': 5,
#   'urbana-champaign illinois area': 26,
#   'greater boston area': 14,
#   'las vegas nevada area': 1,
#   'greater new york city area': 4,
#   'orange county california area': 1,
#   'greater detroit area': 3,
#   'lafayette indiana area': 1,
#   'greater los angeles area': 1,
#   'ottawa canada area': 1,
#   'greater nashville area': 2,
#   'united states': 1,
#   'mumbai area india': 2,
#   'singapore': 1,
#   'washington d.c. metro area': 2,
#   'chandigarh area india': 2,
#   'london united kingdom': 2,
#   'miami fort lauderdale area': 3,
#   'gainesville florida area': 1,
#   'greater atlanta area': 1,
#   'bengaluru area india': 1,
#   'ulm area germany': 1,
#   'bangladesh': 3,
#   'wichita kansas area': 1,
#   'toronto canada area': 1,
#   'lubbock texas area': 1,
#   'british columbia canada': 1,
#   'greater chicago area': 3,
#   'copenhagen area denmark': 1,
#   'bloomington normal illinois area': 1,
#   'greater milwaukee area': 1,
#   'greater salt lake city area': 1,
#   'paris area france': 1,
#   'beijing city china': 1,
#   'providence rhode island area': 1,
#   'greater philadelphia area': 1,
#   'albany new york area': 1},
#  'san francisco bay area': {'urbana-champaign illinois area': 120,
#   'toronto canada area': 2,
#   'bangladesh': 13,
#   'san francisco bay area': 44,
#   'beijing city china': 10,
#   'china': 15,
#   'columbus ohio area': 3,
#   'austin texas area': 5,
#   'greater boston area': 9,
#   'orange county california area': 2,
#   'greater detroit area': 2,
#   'greater new york city area': 7,
#   'shanghai city china': 3,
#   'greater seattle area': 3,
#   'greater san diego area': 3,
#   'hyderabad area india': 3,
#   'noida area india': 2,
#   'hong kong': 2,
#   'brussels area belgium': 1,
#   'greater chicago area': 8,
#   'wichita kansas area': 2,
#   'greater st. louis area': 1,
#   'raleigh-durham north carolina area': 1,
#   'bloomington indiana area': 1,
#   'bengaluru area india': 1,
#   'greater los angeles area': 3,
#   'davenport iowa area': 1,
#   'indianapolis indiana area': 1,
#   'birmingham alabama area': 1,
#   'london united kingdom': 1,
#   'singapore': 1,
#   'yongin gyeonggi-do korea': 1,
#   'british columbia canada': 1,
#   'greater milwaukee area': 1,
#   'copenhagen area denmark': 1,
#   'lubbock texas area': 1,
#   'baton rouge louisiana area': 1,
#   'ithaca new york area': 1,
#   'greater philadelphia area': 1,
#   'albany new york area': 1,
#   'bryan college station texas area': 1,
#   'vietnam': 1,
#   'knoxville tennessee area': 1,
#   'other': 1,
#   'washington d.c. metro area': 2,
#   'paris area france': 1,
#   'providence rhode island area': 1,
#   'finland': 1,
#   'united arab emirates': 1,
#   'charlotte north carolina area': 1,
#   'ontario canada': 1,
#   'eugene oregon area': 1,
#   'iraq': 1,
#   'toledo ohio area': 1,
#   'greater salt lake city area': 1,
#   'greater atlanta area': 1,
#   'iran': 4,
#   'munich area germany': 1,
#   'edmonton canada area': 1,
#   'cleveland akron ohio area': 1,
#   'united states': 1,
#   'kuala lumpur malaysia': 1,
#   'madrid area spain': 1},
#  'shanghai city china': {'beijing city china': 6,
#   'greater atlanta area': 2,
#   'shanghai city china': 6,
#   'urbana-champaign illinois area': 9,
#   'greater san diego area': 3,
#   'china': 13,
#   'greater boston area': 2,
#   'san francisco bay area': 3,
#   'greater new york city area': 2,
#   'greater seattle area': 2,
#   'finland': 2,
#   'tampa st. petersburg florida area': 1},
#  'greater seattle area': {'urbana-champaign illinois area': 28,
#   'san francisco bay area': 3,
#   'greater new york city area': 2,
#   'beijing city china': 1,
#   'greater seattle area': 6,
#   'greater san diego area': 2,
#   'hungary': 2,
#   'greater chicago area': 2,
#   'china': 2,
#   'shanghai city china': 2,
#   'greater los angeles area': 1,
#   'raleigh-durham north carolina area': 1,
#   'ithaca new york area': 1,
#   'greater philadelphia area': 1},
#  'greater san diego area': {'urbana-champaign illinois area': 11,
#   'san francisco bay area': 3,
#   'greater new york city area': 2,
#   'greater seattle area': 2,
#   'shanghai city china': 3,
#   'china': 1,
#   'davenport iowa area': 1,
#   'greater chicago area': 2},
#  'china': {'san francisco bay area': 15,
#   'hong kong': 2,
#   'china': 20,
#   'urbana-champaign illinois area': 33,
#   'greater new york city area': 5,
#   'beijing city china': 13,
#   'greater chicago area': 2,
#   'albany new york area': 1,
#   'brussels area belgium': 1,
#   'greater atlanta area': 3,
#   'greater san diego area': 1,
#   'greater seattle area': 2,
#   'greater boston area': 5,
#   'orange county california area': 1,
#   'shanghai city china': 13,
#   'ithaca new york area': 1,
#   'greater philadelphia area': 1,
#   'greater minneapolis-st. paul area': 1,
#   'greater los angeles area': 1},
#  'urbana-champaign illinois area': {'springfield illinois area': 4,
#   'urbana-champaign illinois area': 752,
#   'decatur illinois area': 10,
#   'kansas city missouri area': 3,
#   'iowa city iowa area': 1,
#   'greater boston area': 14,
#   'greater chicago area': 92,
#   'san francisco bay area': 120,
#   'miami fort lauderdale area': 5,
#   'greater new york city area': 26,
#   'west palm beach florida area': 3,
#   'peoria illinois area': 1,
#   'gainesville florida area': 3,
#   'greater seattle area': 28,
#   'greater atlanta area': 4,
#   'greater los angeles area': 16,
#   'beijing city china': 13,
#   'china': 33,
#   'other': 4,
#   'toronto canada area': 3,
#   'baton rouge louisiana area': 2,
#   'houston texas area': 5,
#   'portland oregon area': 7,
#   'bloomington normal illinois area': 12,
#   'united states': 18,
#   'eugene oregon area': 4,
#   'austin texas area': 4,
#   'raleigh-durham north carolina area': 12,
#   'greater detroit area': 7,
#   'greater philadelphia area': 12,
#   'cincinnati area': 4,
#   'lille area france': 1,
#   'salinas california area': 1,
#   'cleveland akron ohio area': 2,
#   'greater san diego area': 11,
#   'phoenix arizona area': 4,
#   'morelia area mexico': 6,
#   'greater milwaukee area': 7,
#   'bangladesh': 3,
#   'changsha hunan china': 1,
#   'davenport iowa area': 1,
#   'bengaluru area india': 7,
#   'sacramento california area': 3,
#   'greenville south carolina area': 2,
#   'hyderabad area india': 4,
#   'noida area india': 3,
#   'mumbai area india': 1,
#   'greater pittsburgh area': 3,
#   'kandukur area india': 1,
#   'chennai area india': 2,
#   'montreal canada area': 1,
#   'greater st. louis area': 3,
#   'madison wisconsin area': 3,
#   'saginaw michigan area': 1,
#   'tuscaloosa alabama area': 1,
#   'florence south carolina area': 1,
#   'spokane washington area': 1,
#   'mansfield ohio area': 1,
#   'hattiesburg mississippi area': 1,
#   'oklahoma city oklahoma area': 1,
#   'greater nashville area': 3,
#   'knoxville tennessee area': 1,
#   'washington d.c. metro area': 3,
#   'vietnam': 1,
#   'nanjing jiangsu china': 1,
#   'providence rhode island area': 1,
#   'paris area france': 2,
#   'stockholm sweden': 1,
#   'copenhagen area denmark': 1,
#   'greece': 3,
#   'bryan college station texas area': 2,
#   'ithaca new york area': 7,
#   'lafayette indiana area': 1,
#   'shanghai city china': 9,
#   'bloomington indiana area': 1,
#   'finland': 1,
#   'hartford connecticut area': 1,
#   'dresden area germany': 1,
#   'tampa st. petersburg florida area': 1,
#   'shenzhen guangdong china': 1,
#   'orange county california area': 1,
#   'columbus ohio area': 2,
#   'hong kong': 1,
#   'india': 1,
#   'singapore': 1,
#   'mannheim area germany': 1,
#   'new delhi area india': 1,
#   'kitchener canada area': 1,
#   'columbia missouri area': 1,
#   'indianapolis indiana area': 1,
#   'birmingham alabama area': 1,
#   'bologna area italy': 1,
#   'rockford illinois area': 2,
#   'united arab emirates': 1},
#  'greater chicago area': {'urbana-champaign illinois area': 92,
#   'greater new york city area': 3,
#   'greater philadelphia area': 1,
#   'greater seattle area': 2,
#   'san francisco bay area': 8,
#   'bloomington normal illinois area': 2,
#   'springfield illinois area': 5,
#   'greater chicago area': 28,
#   'raleigh-durham north carolina area': 5,
#   'brisbane area australia': 1,
#   'wichita kansas area': 2,
#   'rockford illinois area': 2,
#   'greater st. louis area': 3,
#   'greater milwaukee area': 4,
#   'greater detroit area': 1,
#   'greater los angeles area': 2,
#   'greater san diego area': 2,
#   'greater boston area': 2,
#   'bangladesh': 4,
#   'toronto canada area': 1,
#   'salinas california area': 1,
#   'washington d.c. metro area': 2,
#   'eugene oregon area': 1,
#   'houston texas area': 1,
#   'china': 2,
#   'beijing city china': 1,
#   'norfolk virginia area': 1,
#   'cincinnati area': 1},
#  'greater philadelphia area': {'greater los angeles area': 1,
#   'urbana-champaign illinois area': 12,
#   'greater philadelphia area': 2,
#   'greater chicago area': 1,
#   'ithaca new york area': 1,
#   'greater seattle area': 1,
#   'greater new york city area': 1,
#   'china': 1,
#   'san francisco bay area': 1,
#   'greater boston area': 1,
#   'las vegas nevada area': 1},
#  'norfolk virginia area': {'raleigh-durham north carolina area': 1,
#   'greater chicago area': 1,
#   'greater boston area': 1,
#   'las vegas nevada area': 1},
#  'raleigh-durham north carolina area': {'norfolk virginia area': 1,
#   'greater boston area': 4,
#   'iowa city iowa area': 1,
#   'las vegas nevada area': 1,
#   'urbana-champaign illinois area': 12,
#   'greater chicago area': 5,
#   'greater seattle area': 1,
#   'columbus ohio area': 1,
#   'san francisco bay area': 1,
#   'greater milwaukee area': 1,
#   'greater st. louis area': 1,
#   'greater detroit area': 1,
#   'bloomington indiana area': 1},
#  'greater boston area': {'greater boston area': 44,
#   'greater new york city area': 14,
#   'san francisco bay area': 9,
#   'shanghai city china': 2,
#   'orange county california area': 3,
#   'china': 5,
#   'urbana-champaign illinois area': 14,
#   'baton rouge louisiana area': 2,
#   'norfolk virginia area': 1,
#   'baltimore maryland area': 1,
#   'davenport iowa area': 1,
#   'lincoln nebraska area': 1,
#   'tulsa oklahoma area': 1,
#   'washington d.c. metro area': 4,
#   'austin texas area': 1,
#   'portland maine area': 2,
#   'iowa city iowa area': 3,
#   'lansing michigan area': 1,
#   'germany': 1,
#   'raleigh-durham north carolina area': 4,
#   'barcelona area spain': 1,
#   'greater chicago area': 2,
#   'hyderabad area india': 1,
#   'greater los angeles area': 1,
#   'united arab emirates': 2,
#   'madison wisconsin area': 1,
#   'provo utah area': 1,
#   'nijmegen area netherlands': 1,
#   'edmonton canada area': 1,
#   'greater philadelphia area': 1,
#   'lawrence kansas area': 1,
#   'brazil': 1,
#   'phoenix arizona area': 1,
#   'athens georgia area': 1,
#   'ncr - national capital region philippines': 1,
#   'las vegas nevada area': 1,
#   'albany new york area': 1,
#   'united states': 2,
#   'san antonio texas area': 1,
#   'greater detroit area': 2,
#   'peoria illinois area': 2,
#   'greater nashville area': 1},
#  'las vegas nevada area': {'norfolk virginia area': 1,
#   'greater new york city area': 1,
#   'greater boston area': 1,
#   'greater minneapolis-st. paul area': 1,
#   'raleigh-durham north carolina area': 1,
#   'lansing michigan area': 1,
#   'cambridge united kingdom': 1,
#   'greater philadelphia area': 1,
#   'washington d.c. metro area': 1},
#  'bologna area italy': {'urbana-champaign illinois area': 1},
#  'stockholm sweden': {'urbana-champaign illinois area': 1, 'greece': 3},
#  'greece': {'stockholm sweden': 3,
#   'urbana-champaign illinois area': 3,
#   'greece': 2},
#  'greater los angeles area': {'urbana-champaign illinois area': 16,
#   'greater chicago area': 2,
#   'greater detroit area': 1,
#   'providence rhode island area': 1,
#   'greater seattle area': 1,
#   'beijing city china': 1,
#   'san francisco bay area': 3,
#   'greater boston area': 1,
#   'washington d.c. metro area': 1,
#   'greater new york city area': 1,
#   'china': 1,
#   'greater philadelphia area': 1,
#   'bengaluru area india': 2},
#  'springfield illinois area': {'greater chicago area': 5,
#   'urbana-champaign illinois area': 4},
#  'bengaluru area india': {'urbana-champaign illinois area': 7,
#   'montreal canada area': 1,
#   'mumbai area india': 2,
#   'greater new york city area': 1,
#   'ulm area germany': 1,
#   'london united kingdom': 1,
#   'san francisco bay area': 1,
#   'greater los angeles area': 2,
#   'noida area india': 1},
#  'baltimore maryland area': {'greater boston area': 1},
#  'orange county california area': {'greater boston area': 3,
#   'greater new york city area': 1,
#   'san francisco bay area': 2,
#   'china': 1,
#   'urbana-champaign illinois area': 1},
#  'bloomington normal illinois area': {'greater chicago area': 2,
#   'urbana-champaign illinois area': 12,
#   'madison wisconsin area': 1,
#   'greater new york city area': 1,
#   'greater milwaukee area': 1},
#  'decatur illinois area': {'urbana-champaign illinois area': 10},
#  'kansas city missouri area': {'urbana-champaign illinois area': 3},
#  'iowa city iowa area': {'urbana-champaign illinois area': 1,
#   'greater boston area': 3,
#   'raleigh-durham north carolina area': 1},
#  'hong kong': {'china': 2,
#   'san francisco bay area': 2,
#   'beijing city china': 1,
#   'urbana-champaign illinois area': 1},
#  'beijing city china': {'urbana-champaign illinois area': 13,
#   'greater chicago area': 1,
#   'beijing city china': 4,
#   'san francisco bay area': 10,
#   'greater los angeles area': 1,
#   'austin texas area': 1,
#   'brisbane area australia': 1,
#   'china': 13,
#   'shanghai city china': 6,
#   'shanghai suburb china': 2,
#   'washington d.c. metro area': 1,
#   'greater detroit area': 1,
#   'greater new york city area': 1,
#   'paris area france': 1,
#   'providence rhode island area': 1,
#   'hong kong': 1,
#   'greater seattle area': 1,
#   'finland': 1},
#  'miami fort lauderdale area': {'urbana-champaign illinois area': 5,
#   'greater new york city area': 3,
#   'miami fort lauderdale area': 14,
#   'greater atlanta area': 4},
#  'west palm beach florida area': {'urbana-champaign illinois area': 3,
#   'greater detroit area': 1},
#  'peoria illinois area': {'greater boston area': 2,
#   'urbana-champaign illinois area': 1},
#  'gainesville florida area': {'urbana-champaign illinois area': 3,
#   'greater new york city area': 1},
#  'greater atlanta area': {'urbana-champaign illinois area': 4,
#   'shanghai city china': 2,
#   'china': 3,
#   'toledo ohio area': 1,
#   'kuala lumpur malaysia': 1,
#   'san francisco bay area': 1,
#   'greater new york city area': 1,
#   'miami fort lauderdale area': 4},
#  'toronto canada area': {'san francisco bay area': 2,
#   'urbana-champaign illinois area': 3,
#   'singapore': 1,
#   'greater new york city area': 1,
#   'bangladesh': 4,
#   'greater chicago area': 1,
#   'greater milwaukee area': 1,
#   'baton rouge louisiana area': 1,
#   'copenhagen area denmark': 1},
#  'bangladesh': {'bangladesh': 36,
#   'san francisco bay area': 13,
#   'greater chicago area': 4,
#   'greater new york city area': 3,
#   'urbana-champaign illinois area': 3,
#   'toronto canada area': 4,
#   'baton rouge louisiana area': 2,
#   'greater milwaukee area': 2,
#   'singapore': 2,
#   'wichita kansas area': 1,
#   'yongin gyeonggi-do korea': 1,
#   'british columbia canada': 1,
#   'copenhagen area denmark': 1,
#   'lubbock texas area': 1},
#  'montreal canada area': {'urbana-champaign illinois area': 1,
#   'washington d.c. metro area': 1,
#   'bengaluru area india': 1,
#   'ulm area germany': 1,
#   'mumbai area india': 1},
#  'mumbai area india': {'bengaluru area india': 2,
#   'mumbai area india': 4,
#   'singapore': 3,
#   'greater new york city area': 2,
#   'ulm area germany': 2,
#   'chandigarh area india': 2,
#   'urbana-champaign illinois area': 1,
#   'montreal canada area': 1,
#   'london united kingdom': 1},
#  'ulm area germany': {'bengaluru area india': 1,
#   'mumbai area india': 2,
#   'montreal canada area': 1,
#   'singapore': 1,
#   'greater new york city area': 1,
#   'chandigarh area india': 1,
#   'london united kingdom': 1},
#  'london united kingdom': {'san francisco bay area': 1,
#   'bengaluru area india': 1,
#   'greater new york city area': 2,
#   'ulm area germany': 1,
#   'indianapolis indiana area': 1,
#   'mumbai area india': 1},
#  'davenport iowa area': {'greater boston area': 1,
#   'greater san diego area': 1,
#   'san francisco bay area': 1,
#   'urbana-champaign illinois area': 1},
#  'other': {'urbana-champaign illinois area': 4, 'san francisco bay area': 1},
#  'baton rouge louisiana area': {'greater boston area': 2,
#   'urbana-champaign illinois area': 2,
#   'birmingham alabama area': 1,
#   'toronto canada area': 1,
#   'san francisco bay area': 1,
#   'bangladesh': 2},
#  'houston texas area': {'urbana-champaign illinois area': 5,
#   'greater chicago area': 1},
#  'portland oregon area': {'urbana-champaign illinois area': 7},
#  'madison wisconsin area': {'bloomington normal illinois area': 1,
#   'urbana-champaign illinois area': 3,
#   'greater boston area': 1},
#  'ottawa canada area': {'greater new york city area': 1},
#  'washington d.c. metro area': {'greater los angeles area': 1,
#   'toledo ohio area': 1,
#   'san francisco bay area': 2,
#   'greater boston area': 4,
#   'greater new york city area': 2,
#   'providence rhode island area': 1,
#   'urbana-champaign illinois area': 3,
#   'beijing city china': 1,
#   'paris area france': 1,
#   'greater chicago area': 2,
#   'washington d.c. metro area': 2,
#   'montreal canada area': 1,
#   'greater minneapolis-st. paul area': 1,
#   'lansing michigan area': 1,
#   'las vegas nevada area': 1},
#  'toledo ohio area': {'washington d.c. metro area': 1,
#   'charlotte north carolina area': 1,
#   'iraq': 1,
#   'greater atlanta area': 1,
#   'munich area germany': 1,
#   'san francisco bay area': 1},
#  'united states': {'urbana-champaign illinois area': 18,
#   'morelia area mexico': 1,
#   'greater boston area': 2,
#   'greater new york city area': 1,
#   'greater nashville area': 1,
#   'san francisco bay area': 1},
#  'eugene oregon area': {'urbana-champaign illinois area': 4,
#   'greater chicago area': 1,
#   'san francisco bay area': 1},
#  'austin texas area': {'urbana-champaign illinois area': 4,
#   'austin texas area': 2,
#   'greater boston area': 1,
#   'beijing city china': 1,
#   'san francisco bay area': 5},
#  'greater detroit area': {'urbana-champaign illinois area': 7,
#   'greater los angeles area': 1,
#   'beijing city china': 1,
#   'greater new york city area': 3,
#   'providence rhode island area': 1,
#   'greater chicago area': 1,
#   'san francisco bay area': 2,
#   'raleigh-durham north carolina area': 1,
#   'west palm beach florida area': 1,
#   'bloomington indiana area': 1,
#   'greater salt lake city area': 1,
#   'greater boston area': 2},
#  'greater minneapolis-st. paul area': {'china': 1,
#   'las vegas nevada area': 1,
#   'cambridge united kingdom': 1,
#   'washington d.c. metro area': 1},
#  'saginaw michigan area': {'urbana-champaign illinois area': 1},
#  'ithaca new york area': {'urbana-champaign illinois area': 7,
#   'greater seattle area': 1,
#   'greater philadelphia area': 1,
#   'china': 1,
#   'san francisco bay area': 1},
#  'lincoln nebraska area': {'greater boston area': 1},
#  'brisbane area australia': {'greater chicago area': 1,
#   'beijing city china': 1},
#  'rockford illinois area': {'urbana-champaign illinois area': 2,
#   'greater chicago area': 2,
#   'wichita kansas area': 1},
#  'finland': {'iran': 2,
#   'san francisco bay area': 1,
#   'beijing city china': 1,
#   'urbana-champaign illinois area': 1,
#   'shanghai city china': 2},
#  'iran': {'finland': 2, 'iran': 2, 'san francisco bay area': 4},
#  'cincinnati area': {'urbana-champaign illinois area': 4,
#   'greater chicago area': 1},
#  'lille area france': {'urbana-champaign illinois area': 1},
#  'columbus ohio area': {'urbana-champaign illinois area': 2,
#   'san francisco bay area': 3,
#   'raleigh-durham north carolina area': 1},
#  'lafayette indiana area': {'greater new york city area': 1,
#   'urbana-champaign illinois area': 1},
#  'tulsa oklahoma area': {'greater boston area': 1},
#  'greater st. louis area': {'urbana-champaign illinois area': 3,
#   'greater chicago area': 3,
#   'raleigh-durham north carolina area': 1,
#   'san francisco bay area': 1},
#  'columbia missouri area': {'urbana-champaign illinois area': 1},
#  'indianapolis indiana area': {'urbana-champaign illinois area': 1,
#   'san francisco bay area': 1,
#   'london united kingdom': 1},
#  'knoxville tennessee area': {'urbana-champaign illinois area': 1,
#   'san francisco bay area': 1},
#  'providence rhode island area': {'greater los angeles area': 1,
#   'washington d.c. metro area': 1,
#   'beijing city china': 1,
#   'greater detroit area': 1,
#   'urbana-champaign illinois area': 1,
#   'greater new york city area': 1,
#   'paris area france': 1,
#   'san francisco bay area': 1},
#  'sacramento california area': {'cleveland akron ohio area': 1,
#   'urbana-champaign illinois area': 3},
#  'cleveland akron ohio area': {'sacramento california area': 1,
#   'urbana-champaign illinois area': 2,
#   'san francisco bay area': 1},
#  'birmingham alabama area': {'baton rouge louisiana area': 1,
#   'san francisco bay area': 1,
#   'urbana-champaign illinois area': 1},
#  'hungary': {'greater seattle area': 2},
#  'wichita kansas area': {'singapore': 1,
#   'british columbia canada': 1,
#   'greater milwaukee area': 1,
#   'greater new york city area': 1,
#   'bangladesh': 1,
#   'san francisco bay area': 2,
#   'greater chicago area': 2,
#   'rockford illinois area': 1},
#  'salinas california area': {'urbana-champaign illinois area': 1,
#   'greater chicago area': 1},
#  'copenhagen area denmark': {'urbana-champaign illinois area': 1,
#   'yongin gyeonggi-do korea': 1,
#   'greater new york city area': 1,
#   'toronto canada area': 1,
#   'san francisco bay area': 1,
#   'british columbia canada': 1,
#   'bangladesh': 1},
#  'india': {'urbana-champaign illinois area': 1},
#  'singapore': {'urbana-champaign illinois area': 1,
#   'wichita kansas area': 1,
#   'toronto canada area': 1,
#   'bangladesh': 2,
#   'san francisco bay area': 1,
#   'mumbai area india': 3,
#   'greater new york city area': 1,
#   'ulm area germany': 1,
#   'chandigarh area india': 1},
#  'shanghai suburb china': {'beijing city china': 2},
#  'portland maine area': {'greater boston area': 2},
#  'lansing michigan area': {'greater boston area': 1,
#   'las vegas nevada area': 1,
#   'cambridge united kingdom': 1,
#   'washington d.c. metro area': 1},
#  'germany': {'greater boston area': 1},
#  'barcelona area spain': {'greater boston area': 1},
#  'hyderabad area india': {'greater boston area': 1,
#   'urbana-champaign illinois area': 4,
#   'noida area india': 2,
#   'san francisco bay area': 3},
#  'united arab emirates': {'san francisco bay area': 1,
#   'urbana-champaign illinois area': 1,
#   'greater boston area': 2},
#  'provo utah area': {'greater boston area': 1},
#  'nijmegen area netherlands': {'greater boston area': 1},
#  'edmonton canada area': {'san francisco bay area': 1,
#   'greater boston area': 1},
#  'lawrence kansas area': {'greater boston area': 1},
#  'brazil': {'greater boston area': 1},
#  'phoenix arizona area': {'urbana-champaign illinois area': 4,
#   'greater boston area': 1},
#  'athens georgia area': {'greater boston area': 1},
#  'ncr - national capital region philippines': {'greater boston area': 1},
#  'albany new york area': {'greater boston area': 1,
#   'china': 1,
#   'san francisco bay area': 1,
#   'greater new york city area': 1},
#  'san antonio texas area': {'greater boston area': 1},
#  'greater salt lake city area': {'greater detroit area': 1,
#   'greater new york city area': 1,
#   'san francisco bay area': 1},
#  'morelia area mexico': {'united states': 1,
#   'urbana-champaign illinois area': 6,
#   'greater milwaukee area': 1},
#  'greater milwaukee area': {'greater chicago area': 4,
#   'raleigh-durham north carolina area': 1,
#   'wichita kansas area': 1,
#   'toronto canada area': 1,
#   'san francisco bay area': 1,
#   'bangladesh': 2,
#   'british columbia canada': 1,
#   'bloomington normal illinois area': 1,
#   'urbana-champaign illinois area': 7,
#   'greater new york city area': 1,
#   'morelia area mexico': 1},
#  'cambridge united kingdom': {'greater minneapolis-st. paul area': 1,
#   'lansing michigan area': 1,
#   'las vegas nevada area': 1},
#  'noida area india': {'san francisco bay area': 2,
#   'bengaluru area india': 1,
#   'hyderabad area india': 2,
#   'urbana-champaign illinois area': 3},
#  'paris area france': {'urbana-champaign illinois area': 2,
#   'washington d.c. metro area': 1,
#   'beijing city china': 1,
#   'greater new york city area': 1,
#   'san francisco bay area': 1,
#   'providence rhode island area': 1},
#  'charlotte north carolina area': {'munich area germany': 1,
#   'toledo ohio area': 1,
#   'san francisco bay area': 1},
#  'munich area germany': {'charlotte north carolina area': 1,
#   'toledo ohio area': 1,
#   'san francisco bay area': 1},
#  'greater pittsburgh area': {'urbana-champaign illinois area': 3,
#   'chennai area india': 1},
#  'greater nashville area': {'greater new york city area': 2,
#   'united states': 1,
#   'greater boston area': 1,
#   'urbana-champaign illinois area': 3},
#  'brussels area belgium': {'san francisco bay area': 1,
#   'china': 1,
#   'shenzhen guangdong china': 1},
#  'tuscaloosa alabama area': {'urbana-champaign illinois area': 1},
#  'chandigarh area india': {'mumbai area india': 2,
#   'greater new york city area': 2,
#   'ulm area germany': 1,
#   'singapore': 1},
#  'bloomington indiana area': {'urbana-champaign illinois area': 1,
#   'san francisco bay area': 1,
#   'greater detroit area': 1,
#   'raleigh-durham north carolina area': 1},
#  'greenville south carolina area': {'urbana-champaign illinois area': 2},
#  'vietnam': {'san francisco bay area': 1, 'urbana-champaign illinois area': 1},
#  'ontario canada': {'san francisco bay area': 1},
#  'mannheim area germany': {'urbana-champaign illinois area': 1},
#  'shenzhen guangdong china': {'brussels area belgium': 1,
#   'urbana-champaign illinois area': 1},
#  'iraq': {'toledo ohio area': 1, 'san francisco bay area': 1},
#  'british columbia canada': {'wichita kansas area': 1,
#   'greater new york city area': 1,
#   'san francisco bay area': 1,
#   'copenhagen area denmark': 1,
#   'bangladesh': 1,
#   'greater milwaukee area': 1},
#  'changsha hunan china': {'urbana-champaign illinois area': 1},
#  'chennai area india': {'urbana-champaign illinois area': 2,
#   'greater pittsburgh area': 1},
#  'nanjing jiangsu china': {'urbana-champaign illinois area': 1},
#  'yongin gyeonggi-do korea': {'bangladesh': 1,
#   'copenhagen area denmark': 1,
#   'san francisco bay area': 1},
#  'lubbock texas area': {'greater new york city area': 1,
#   'san francisco bay area': 1,
#   'bangladesh': 1},
#  'hartford connecticut area': {'urbana-champaign illinois area': 1},
#  'bryan college station texas area': {'urbana-champaign illinois area': 2,
#   'san francisco bay area': 1},
#  'dresden area germany': {'urbana-champaign illinois area': 1},
#  'florence south carolina area': {'urbana-champaign illinois area': 1},
#  'spokane washington area': {'urbana-champaign illinois area': 1},
#  'kuala lumpur malaysia': {'greater atlanta area': 1,
#   'san francisco bay area': 1},
#  'kandukur area india': {'urbana-champaign illinois area': 1},
#  'tampa st. petersburg florida area': {'urbana-champaign illinois area': 1,
#   'shanghai city china': 1},
#  'mansfield ohio area': {'urbana-champaign illinois area': 1},
#  'hattiesburg mississippi area': {'urbana-champaign illinois area': 1},
#  'oklahoma city oklahoma area': {'urbana-champaign illinois area': 1},
#  'new delhi area india': {'urbana-champaign illinois area': 1},
#  'kitchener canada area': {'urbana-champaign illinois area': 1},
#  'madrid area spain': {'san francisco bay area': 1}}

# %%
nx.degree_mixing_dict(graph_all)
# Out:
# {1: {28: 12,
#   46: 46,
#   58: 39,
#   2: 11,
#   122: 43,
#   37: 7,
#   8: 9,
#   29: 9,
#   6: 8,
#   3: 6,
#   74: 66,
#   45: 35,
#   20: 9,
#   4: 5,
#   10: 8,
#   23: 5,
#   5: 5,
#   16: 5,
#   18: 2,
#   7: 2,
#   9: 1,
#   31: 2,
#   17: 3,
#   32: 2,
#   11: 1},
#  28: {1: 12, 2: 9, 4: 3, 6: 2, 3: 2},
#  9: {14: 6,
#   7: 13,
#   10: 12,
#   8: 12,
#   32: 2,
#   6: 9,
#   22: 2,
#   31: 3,
#   3: 9,
#   9: 12,
#   13: 4,
#   5: 9,
#   122: 4,
#   17: 4,
#   4: 9,
#   1: 1,
#   2: 6,
#   29: 1,
#   16: 4,
#   11: 1,
#   46: 3,
#   12: 5,
#   23: 1,
#   58: 1,
#   20: 1,
#   37: 1},
#  14: {8: 2,
#   3: 4,
#   2: 2,
#   9: 6,
#   18: 1,
#   19: 1,
#   5: 6,
#   7: 6,
#   4: 4,
#   37: 1,
#   122: 1,
#   6: 17,
#   12: 3,
#   10: 4,
#   14: 6,
#   32: 3,
#   17: 1,
#   16: 1,
#   46: 1},
#  7: {16: 5,
#   5: 19,
#   22: 2,
#   2: 8,
#   6: 22,
#   46: 2,
#   31: 4,
#   9: 13,
#   10: 9,
#   19: 2,
#   8: 5,
#   122: 4,
#   14: 6,
#   4: 16,
#   32: 4,
#   7: 10,
#   3: 12,
#   37: 1,
#   13: 4,
#   1: 2,
#   23: 1,
#   12: 1,
#   17: 3,
#   29: 2,
#   20: 2,
#   45: 1,
#   11: 1},
#  10: {20: 1,
#   10: 16,
#   12: 8,
#   37: 1,
#   4: 8,
#   13: 16,
#   122: 7,
#   24: 6,
#   7: 9,
#   5: 11,
#   9: 12,
#   1: 8,
#   2: 8,
#   6: 13,
#   8: 7,
#   11: 4,
#   22: 2,
#   3: 7,
#   17: 3,
#   31: 1,
#   14: 4,
#   32: 2,
#   18: 1,
#   16: 2,
#   46: 1,
#   29: 1,
#   19: 1},
#  8: {3: 13,
#   6: 20,
#   10: 7,
#   19: 4,
#   7: 5,
#   8: 8,
#   5: 14,
#   9: 12,
#   4: 8,
#   122: 5,
#   22: 1,
#   11: 1,
#   17: 4,
#   31: 1,
#   13: 3,
#   37: 2,
#   20: 2,
#   12: 6,
#   2: 8,
#   1: 9,
#   16: 1,
#   46: 1,
#   18: 3,
#   24: 2,
#   32: 1,
#   74: 1,
#   14: 2},
#  32: {5: 3, 6: 10, 9: 2, 3: 4, 1: 2, 4: 1, 10: 2, 14: 3, 7: 4, 8: 1},
#  6: {8: 20,
#   3: 22,
#   7: 22,
#   19: 4,
#   18: 1,
#   9: 9,
#   12: 2,
#   13: 2,
#   122: 3,
#   6: 56,
#   10: 13,
#   4: 32,
#   2: 16,
#   5: 16,
#   14: 17,
#   32: 10,
#   17: 4,
#   29: 3,
#   20: 4,
#   46: 4,
#   11: 1,
#   28: 2,
#   1: 8,
#   37: 1,
#   16: 2,
#   74: 1,
#   45: 1},
#  46: {16: 3,
#   1: 46,
#   2: 12,
#   22: 1,
#   13: 1,
#   17: 2,
#   7: 2,
#   6: 4,
#   10: 1,
#   31: 1,
#   9: 3,
#   20: 1,
#   3: 11,
#   4: 2,
#   8: 1,
#   14: 1},
#  5: {10: 11,
#   12: 7,
#   7: 19,
#   2: 17,
#   3: 23,
#   5: 16,
#   4: 22,
#   8: 14,
#   122: 11,
#   20: 4,
#   16: 3,
#   17: 3,
#   22: 1,
#   31: 1,
#   74: 2,
#   6: 16,
#   1: 5,
#   45: 2,
#   11: 3,
#   24: 3,
#   9: 9,
#   18: 2,
#   14: 6,
#   37: 4,
#   29: 2,
#   58: 2,
#   32: 3,
#   19: 2,
#   13: 1,
#   23: 1},
#  12: {10: 8,
#   6: 2,
#   13: 5,
#   24: 2,
#   37: 2,
#   122: 2,
#   20: 2,
#   8: 6,
#   9: 5,
#   2: 6,
#   4: 8,
#   14: 3,
#   5: 7,
#   17: 2,
#   16: 2,
#   12: 2,
#   3: 6,
#   11: 1,
#   7: 1},
#  2: {58: 7,
#   4: 16,
#   10: 8,
#   12: 6,
#   28: 9,
#   3: 25,
#   5: 17,
#   6: 16,
#   2: 38,
#   18: 4,
#   122: 18,
#   1: 11,
#   11: 1,
#   22: 1,
#   24: 1,
#   46: 12,
#   20: 6,
#   9: 6,
#   37: 8,
#   8: 8,
#   17: 4,
#   7: 8,
#   19: 1,
#   16: 2,
#   31: 1,
#   23: 5,
#   45: 2,
#   74: 2,
#   29: 4,
#   13: 1,
#   14: 2},
#  3: {3: 46,
#   122: 7,
#   5: 23,
#   16: 4,
#   14: 4,
#   46: 11,
#   9: 9,
#   8: 13,
#   32: 4,
#   6: 22,
#   4: 16,
#   19: 3,
#   23: 5,
#   12: 6,
#   28: 2,
#   2: 25,
#   10: 7,
#   7: 12,
#   11: 3,
#   31: 5,
#   1: 6,
#   37: 4,
#   17: 5,
#   29: 3,
#   13: 2,
#   58: 6,
#   22: 1,
#   45: 1},
#  4: {8: 8,
#   19: 1,
#   6: 32,
#   20: 3,
#   7: 16,
#   3: 16,
#   5: 22,
#   12: 8,
#   1: 5,
#   122: 9,
#   37: 1,
#   14: 4,
#   17: 6,
#   9: 9,
#   4: 16,
#   10: 8,
#   2: 16,
#   32: 1,
#   58: 3,
#   22: 4,
#   11: 6,
#   31: 6,
#   28: 3,
#   16: 3,
#   46: 2,
#   29: 3,
#   23: 4,
#   45: 2,
#   24: 3,
#   13: 4},
#  19: {8: 4, 2: 1, 3: 3, 7: 2, 6: 4, 10: 1, 5: 2, 4: 1, 14: 1},
#  20: {7: 2,
#   6: 4,
#   1: 9,
#   46: 1,
#   4: 3,
#   2: 6,
#   10: 1,
#   8: 2,
#   5: 4,
#   9: 1,
#   18: 1,
#   13: 1,
#   37: 1,
#   23: 1,
#   122: 1,
#   12: 2},
#  37: {10: 1,
#   2: 8,
#   3: 4,
#   5: 4,
#   1: 7,
#   9: 1,
#   7: 1,
#   24: 1,
#   4: 1,
#   13: 1,
#   8: 2,
#   20: 1,
#   122: 1,
#   12: 2,
#   14: 1,
#   6: 1},
#  13: {10: 16,
#   18: 1,
#   6: 2,
#   24: 4,
#   9: 4,
#   122: 4,
#   12: 5,
#   8: 3,
#   74: 1,
#   13: 4,
#   7: 4,
#   16: 1,
#   11: 2,
#   22: 1,
#   17: 1,
#   31: 1,
#   4: 4,
#   46: 1,
#   3: 2,
#   5: 1,
#   20: 1,
#   37: 1,
#   2: 1},
#  122: {8: 5,
#   10: 7,
#   2: 18,
#   1: 43,
#   4: 9,
#   5: 11,
#   3: 7,
#   6: 3,
#   9: 4,
#   18: 1,
#   13: 4,
#   7: 4,
#   24: 1,
#   37: 1,
#   14: 1,
#   20: 1,
#   12: 2},
#  24: {10: 6, 5: 3, 4: 3, 2: 1, 18: 1, 13: 4, 8: 2, 37: 1, 122: 1, 12: 2},
#  58: {4: 3, 1: 39, 3: 6, 2: 7, 5: 2, 9: 1},
#  16: {10: 2,
#   2: 2,
#   5: 3,
#   3: 4,
#   17: 2,
#   4: 3,
#   6: 2,
#   14: 1,
#   46: 3,
#   9: 4,
#   12: 2,
#   8: 1,
#   16: 2,
#   22: 2,
#   7: 5,
#   31: 2,
#   13: 1,
#   11: 2,
#   1: 5},
#  22: {7: 2,
#   16: 2,
#   4: 4,
#   5: 1,
#   9: 2,
#   11: 2,
#   17: 1,
#   8: 1,
#   31: 1,
#   13: 1,
#   10: 2,
#   3: 1,
#   46: 1,
#   2: 1},
#  31: {7: 4,
#   16: 2,
#   4: 6,
#   5: 1,
#   3: 5,
#   1: 2,
#   9: 3,
#   11: 2,
#   22: 1,
#   13: 1,
#   46: 1,
#   8: 1,
#   2: 1,
#   10: 1},
#  11: {4: 6,
#   16: 2,
#   22: 2,
#   8: 1,
#   31: 2,
#   17: 2,
#   10: 4,
#   13: 2,
#   7: 1,
#   3: 3,
#   9: 1,
#   5: 3,
#   2: 1,
#   6: 1,
#   1: 1,
#   12: 1},
#  17: {9: 4,
#   1: 3,
#   4: 6,
#   5: 3,
#   7: 3,
#   8: 4,
#   6: 4,
#   2: 4,
#   3: 5,
#   29: 1,
#   10: 3,
#   14: 1,
#   46: 2,
#   16: 2,
#   12: 2,
#   11: 2,
#   22: 1,
#   13: 1},
#  29: {17: 1, 1: 9, 2: 4, 9: 1, 3: 3, 4: 3, 7: 2, 5: 2, 6: 3, 10: 1},
#  18: {8: 3, 10: 1, 5: 2, 2: 4, 1: 2, 20: 1, 6: 1, 122: 1, 14: 1, 24: 1, 13: 1},
#  74: {1: 66, 6: 1, 5: 2, 2: 2, 13: 1, 8: 1, 45: 1},
#  45: {1: 35, 5: 2, 6: 1, 3: 1, 2: 2, 7: 1, 4: 2, 74: 1},
#  23: {4: 4, 1: 5, 2: 5, 3: 5, 9: 1, 5: 1, 20: 1, 7: 1}}

# %%
nx.degree_pearson_correlation_coefficient(graph_all)
# Out:
# -0.22480574380333795

# %%
nx.degree_assortativity_coefficient(graph_all)
# Out:
# -0.22480574380333795

# %%
c = list(nx.algorithms.community.k_clique_communities(graph_all, 4))
c
# Out:
# [frozenset({'U15267',
#             'U15269',
#             'U15272',
#             'U15284',
#             'U15286',
#             'U15287',
#             'U15292',
#             'U15294',
#             'U15296',
#             'U15297',
#             'U15299',
#             'U15307',
#             'U15308',
#             'U15316',
#             'U15317',
#             'U15318',
#             'U15321',
#             'U15333',
#             'U15334',
#             'U15335',
#             'U15336',
#             'U15341',
#             'U15342',
#             'U15344',
#             'U15349',
#             'U15350',
#             'U15359',
#             'U8702'}),
#  frozenset({'U14123', 'U15168', 'U9630', 'U9710'}),
#  frozenset({'U11558',
#             'U11564',
#             'U3894',
#             'U3895',
#             'U3939',
#             'U3954',
#             'U3955',
#             'U4005',
#             'U4010'}),
#  frozenset({'U18514',
#             'U18516',
#             'U18518',
#             'U18524',
#             'U18549',
#             'U18560',
#             'U18562',
#             'U18570'}),
#  frozenset({'U19874', 'U19913', 'U7202', 'U9710'}),
#  frozenset({'U14477',
#             'U14479',
#             'U14490',
#             'U14492',
#             'U14496',
#             'U14498',
#             'U14499',
#             'U14500',
#             'U14507',
#             'U14519',
#             'U14520',
#             'U14526',
#             'U14529',
#             'U14531',
#             'U14532',
#             'U14542',
#             'U14566',
#             'U4249',
#             'U5976',
#             'U5977',
#             'U5980',
#             'U5981',
#             'U5982',
#             'U5983',
#             'U5996',
#             'U6000',
#             'U6001',
#             'U6021',
#             'U7972',
#             'U7986',
#             'U7987',
#             'U8048'}),
#  frozenset({'U13959',
#             'U13961',
#             'U13968',
#             'U13969',
#             'U13981',
#             'U13988',
#             'U13993',
#             'U13995',
#             'U14005',
#             'U14007',
#             'U14015',
#             'U14024',
#             'U18539',
#             'U24154',
#             'U8670',
#             'U8699',
#             'U8710',
#             'U8741',
#             'U8795'}),
#  frozenset({'U10059', 'U2108', 'U2136', 'U2140', 'U2180'}),
#  frozenset({'U24152', 'U24158', 'U24198', 'U8670'}),
#  frozenset({'U11597', 'U3918', 'U3919', 'U3955'}),
#  frozenset({'U14577',
#             'U16219',
#             'U18928',
#             'U18939',
#             'U18942',
#             'U18943',
#             'U18949',
#             'U18965',
#             'U27941',
#             'U4485',
#             'U4661',
#             'U7912'}),
#  frozenset({'U1045', 'U1055', 'U10607', 'U1282'}),
#  frozenset({'U3909', 'U3914', 'U3919', 'U3944', 'U3971'}),
#  frozenset({'U4562',
#             'U4563',
#             'U4607',
#             'U4610',
#             'U4619',
#             'U4633',
#             'U4638',
#             'U4647',
#             'U4652'}),
#  frozenset({'U12957', 'U12969', 'U12970', 'U7091', 'U7347'}),
#  frozenset({'U7315', 'U9630', 'U9657', 'U9710'}),
#  frozenset({'U22747', 'U22753', 'U22771', 'U22785', 'U22825'}),
#  frozenset({'U11563',
#             'U11566',
#             'U16127',
#             'U24045',
#             'U24064',
#             'U24080',
#             'U24184',
#             'U24504',
#             'U25563',
#             'U2656',
#             'U27283',
#             'U27287',
#             'U27289',
#             'U27300',
#             'U27471',
#             'U27499',
#             'U27507',
#             'U27508',
#             'U27516',
#             'U27557',
#             'U27582',
#             'U27618',
#             'U27676',
#             'U4562',
#             'U4568',
#             'U4586',
#             'U4613',
#             'U4619',
#             'U4628',
#             'U4665',
#             'U7256',
#             'U7319'}),
#  frozenset({'U15928', 'U15932', 'U15934', 'U15939', 'U15968', 'U15974'}),
#  frozenset({'U10059', 'U2140', 'U21835', 'U21848'}),
#  frozenset({'U9627', 'U9628', 'U9657', 'U9665'}),
#  frozenset({'U16101', 'U16112', 'U16128', 'U16141', 'U16152'}),
#  frozenset({'U24128', 'U24139', 'U24177', 'U8670'}),
#  frozenset({'U4562', 'U4625', 'U4630', 'U4655'}),
#  frozenset({'U15935', 'U15946', 'U15949', 'U15968'}),
#  frozenset({'U19842', 'U19848', 'U19856', 'U19858', 'U19886'}),
#  frozenset({'U1045', 'U10607', 'U1313', 'U1359'}),
#  frozenset({'U14068', 'U14096', 'U14112', 'U14113', 'U14119'}),
#  frozenset({'U11559', 'U11562', 'U2656', 'U27287', 'U4568'}),
#  frozenset({'U27287',
#             'U27456',
#             'U27473',
#             'U27476',
#             'U27477',
#             'U27494',
#             'U27515',
#             'U27525',
#             'U27532',
#             'U27541',
#             'U27603',
#             'U27634',
#             'U27661'}),
#  frozenset({'U27287', 'U27575', 'U27585', 'U27661'}),
#  frozenset({'U27287',
#             'U27460',
#             'U27475',
#             'U27588',
#             'U27613',
#             'U27614',
#             'U27656'}),
#  frozenset({'U11566', 'U16115', 'U16127', 'U16137'}),
#  frozenset({'U14068', 'U14078', 'U14088', 'U14125'})]

# %%
bays = []
nodes_in_bay_all = []
for node in graph_all.nodes:
    node_att = graph_all.nodes[node]
    location = node_att['location'][0]
    if 'bay' in location.lower():
        if location not in bays: bays.append(location)
        nodes_in_bay_all.append(node)
        #print(f'node: {node}, loc: {location}')

print(bays)
# Out:
# ['san francisco bay area', 'green bay wisconsin area']

# %%
key_nodes_in_bay = []
for i, node_element in enumerate(order_arr):
    if node_element['node'] in nodes_in_bay_all:
        #print(f'index: {i}, node_el {node_element}')
        key_nodes_in_bay.append(node_element['node'])

# %%
for i, node_element in enumerate(order_arr):
    node = node_element['node']
    if node in nodes_in_bay_all:
        if 'location' in graph_first.nodes[node]:
            print(f'node: {node}, centrality: {node_element["centr"]}, num_neigh: {len([e for e in graph_first.neighbors(node)])}, location: {graph_first.nodes[node]["location"]}')
        else:
            print('no location')
# Out:
# node: U8670, centrality: 0.056790123456790124, num_neigh: 174, location: ['urbana-champaign illinois area']
# node: U15267, centrality: 0.03950617283950617, num_neigh: 107, location: ['san francisco bay area']
# node: U24045, centrality: 0.02962962962962963, num_neigh: 98, location: ['urbana-champaign illinois area']
# node: U4568, centrality: 0.01728395061728395, num_neigh: 48, location: ['greater new york city area']
# node: U27661, centrality: 0.011111111111111112, num_neigh: 22, location: ['san francisco bay area']
# node: U4619, centrality: 0.009876543209876543, num_neigh: 23, location: ['san francisco bay area']
# node: U16128, centrality: 0.008641975308641974, num_neigh: 27, location: ['china']
# node: U14577, centrality: 0.008641975308641974, num_neigh: 16, location: ['san francisco bay area']
# node: U16141, centrality: 0.008641975308641974, num_neigh: 29, location: ['china']
# node: U15272, centrality: 0.007407407407407408, num_neigh: 20, location: ['san francisco bay area']
# node: U27460, centrality: 0.007407407407407408, num_neigh: 31, location: ['san francisco bay area']
# node: U11558, centrality: 0.007407407407407408, num_neigh: 26, location: ['china']
# node: U22771, centrality: 0.007407407407407408, num_neigh: 24, location: ['san francisco bay area']
# node: U4010, centrality: 0.007407407407407408, num_neigh: 27, location: ['greater boston area']
# node: U27613, centrality: 0.007407407407407408, num_neigh: 30, location: ['san francisco bay area']
# node: U27588, centrality: 0.006172839506172839, num_neigh: 30, location: ['san francisco bay area']
# node: U27614, centrality: 0.006172839506172839, num_neigh: 22, location: ['san francisco bay area']
# no location
# node: U2627, centrality: 0.006172839506172839, num_neigh: 21, location: ['urbana-champaign illinois area']
# node: U24064, centrality: 0.006172839506172839, num_neigh: 27, location: ['san francisco bay area']
# node: U22825, centrality: 0.0049382716049382715, num_neigh: 17, location: ['san francisco bay area']
# node: U19858, centrality: 0.0049382716049382715, num_neigh: 20, location: ['urbana-champaign illinois area']
# node: U27656, centrality: 0.0049382716049382715, num_neigh: 23, location: ['san francisco bay area']
# node: U11575, centrality: 0.003703703703703704, num_neigh: 15, location: ['san francisco bay area']
# node: U27585, centrality: 0.003703703703703704, num_neigh: 7, location: ['san francisco bay area']
# node: U4012, centrality: 0.003703703703703704, num_neigh: 10, location: ['san francisco bay area']
# node: U24084, centrality: 0.003703703703703704, num_neigh: 23, location: ['urbana-champaign illinois area']
# node: U21835, centrality: 0.003703703703703704, num_neigh: 16, location: ['san francisco bay area']
# node: U2691, centrality: 0.003703703703703704, num_neigh: 20, location: ['san francisco bay area']
# node: U15173, centrality: 0.0024691358024691358, num_neigh: 9, location: ['urbana-champaign illinois area']
# node: U27687, centrality: 0.0024691358024691358, num_neigh: 7, location: ['shanghai city china']
# node: U13066, centrality: 0.0024691358024691358, num_neigh: 7, location: ['san francisco bay area']
# node: U2750, centrality: 0.0024691358024691358, num_neigh: 11, location: ['san francisco bay area']
# no location
# node: U2622, centrality: 0.0024691358024691358, num_neigh: 7, location: ['san francisco bay area']
# node: U28776, centrality: 0.0024691358024691358, num_neigh: 7, location: ['san francisco bay area']
# node: U24085, centrality: 0.0024691358024691358, num_neigh: 13, location: ['san francisco bay area']
# node: U4680, centrality: 0.0024691358024691358, num_neigh: 2, location: ['san francisco bay area']
# node: U27602, centrality: 0.0024691358024691358, num_neigh: 9, location: ['urbana-champaign illinois area']
# node: U7082, centrality: 0.0024691358024691358, num_neigh: 11, location: ['san francisco bay area']
# node: U28772, centrality: 0.0024691358024691358, num_neigh: 9, location: ['urbana-champaign illinois area']
# node: U24549, centrality: 0.0012345679012345679, num_neigh: 6, location: ['san francisco bay area']
# no location
# no location
# no location
# node: U14029, centrality: 0.0012345679012345679, num_neigh: 6, location: ['san francisco bay area']
# no location
# no location
# no location
# node: U27748, centrality: 0.0012345679012345679, num_neigh: 2, location: ['urbana-champaign illinois area']
# node: U7132, centrality: 0.0012345679012345679, num_neigh: 5, location: ['urbana-champaign illinois area']
# no location
# node: U27279, centrality: 0.0012345679012345679, num_neigh: 2, location: ['san francisco bay area']
# node: U2761, centrality: 0.0012345679012345679, num_neigh: 5, location: ['san francisco bay area']
# no location
# node: U7049, centrality: 0.0012345679012345679, num_neigh: 2, location: ['san francisco bay area']
# node: U14138, centrality: 0.0012345679012345679, num_neigh: 4, location: ['urbana-champaign illinois area']
# no location
# node: U24113, centrality: 0.0012345679012345679, num_neigh: 5, location: ['san francisco bay area']
# node: U24082, centrality: 0.0012345679012345679, num_neigh: 16, location: ['san francisco bay area']
# node: U27726, centrality: 0.0012345679012345679, num_neigh: 2, location: ['san francisco bay area']
# node: U27642, centrality: 0.0012345679012345679, num_neigh: 6, location: ['san francisco bay area']
# node: U7159, centrality: 0.0012345679012345679, num_neigh: 1, location: ['san francisco bay area']
# node: U28774, centrality: 0.0012345679012345679, num_neigh: 3, location: ['urbana-champaign illinois area']
# no location
# node: U7288, centrality: 0.0012345679012345679, num_neigh: 1, location: ['san francisco bay area']
# node: U2746, centrality: 0.0012345679012345679, num_neigh: 4, location: ['san francisco bay area']
# node: U7180, centrality: 0.0012345679012345679, num_neigh: 1, location: ['san francisco bay area']
# no location
# no location
# no location
# no location
# no location
# no location
# node: U1379, centrality: 0.0012345679012345679, num_neigh: 2, location: ['israel']
# no location
# node: U24224, centrality: 0.0012345679012345679, num_neigh: 3, location: ['san francisco bay area']
# no location
# node: U7189, centrality: 0.0012345679012345679, num_neigh: 1, location: ['san francisco bay area']
